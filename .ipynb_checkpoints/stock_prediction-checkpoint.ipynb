# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error 
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, GRU, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import json
import random

# %% [markdown]
# ## Data Preparation & Preprocessing

# %%
# Set seed for reproducibility
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# %%
# Load the data
data = pd.read_csv('data/SP500.csv')
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

# round to 2 decimal places
data = data.round(2)

# %%
# Preprocess the data
features = data[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']]
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(features)

# Verify that data[:, 3] refers to the 'Close' price
assert(data.columns[3] == 'Close')

# %%
# Create sequences
def create_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length, 3])  # Assuming 'Close' price is the target
    return np.array(X), np.array(y)
 
seq_length = hyperparams['seq_length'] # Extract sequence length
X, y = create_sequences(scaled_data, seq_length)

split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %% [markdown]
# ## LSTM

# %%
# Load & extract hyperparameters

# Load hyperparameters
with open('configs/configs.json', 'r') as file:
    hyperparams = json.load(file)

# Extract hyperparameters
lstm_units = hyperparams['lstm']['lstm_units']
dropout_rate = hyperparams['lstm']['dropout_rate']
dense_units = hyperparams['lstm']['dense_units']
batch_size = hyperparams['lstm']['batch_size']
epochs = hyperparams['lstm']['epochs']
use_early_stop = hyperparams['lstm']['use_early_stop']
early_stop_patience = hyperparams['lstm']['early_stop_patience']
train_needed = hyperparams['lstm']['pretrain'] # Whether to train the model

# %%
# Build the LSTM model (or load the saved model)
if train_needed:
    model = Sequential()
    model.add(LSTM(lstm_units, return_sequences=True, input_shape=(seq_length, 6)))
    model.add(Dropout(dropout_rate))
    model.add(LSTM(lstm_units, return_sequences=False))
    model.add(Dropout(dropout_rate))
    model.add(Dense(dense_units))
    model.add(Dense(1))
    
    model.compile(optimizer='adam', loss='mean_squared_error')
else:
    model = load_model('models/SP500_LSTM_model.h5')

# %%
# 6. Train the model if needed
if train_needed:
    if use_early_stop:
        early_stop = EarlyStopping(monitor='val_loss', patience=early_stop_patience)
        history = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_test, y_test), callbacks=[early_stop])
    else:
        history = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_test, y_test))

# %%
# Save model for future use
model.save('models/SP500_LSTM_model.h5')
# Out:
# /Users/michaelzhou/miniforge3/envs/tf_m1/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# 7. Evaluate the model 
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# %%
# 8. Make predictions
predictions = model.predict(X_test)

# Inverse transform predictions to the original scale
predictions_rescaled = np.zeros_like(scaled_data)
predictions_rescaled[:, 3] = np.nan  # Fill the 'Close' column
predictions_rescaled[split+seq_length:, 3] = predictions[:, -1]
predictions_rescaled = scaler.inverse_transform(predictions_rescaled)

# Extract actual close prices and ensure they're in the right shape for comparison
actual_prices = scaled_data[split+seq_length:, 3]
actual_prices_rescaled = scaler.inverse_transform(np.hstack((np.zeros((len(actual_prices), scaled_data.shape[1] - 1)), actual_prices.reshape(-1, 1))))
actual_prices_rescaled = actual_prices_rescaled[:, -1]
# Out:
# 2024-07-05 15:46:38.750871: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-07-05 15:46:38.825297: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-07-05 15:46:38.919595: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 106/106 [==============================] - 2s 15ms/step

# %%
# 9. Visualize the results
plt.figure(figsize=(14, 7))
plt.plot(actual_prices, label='Actual Close Price')
plt.plot(predictions[:, -1], label='Predicted Close Price')
plt.legend()
plt.show()

# %%
# 10. Final evaluation of model
mae = mean_absolute_error(actual_prices, predictions[:, -1])
mse = mean_squared_error(actual_prices, predictions[:, -1])
rmse = np.sqrt(mse)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Mean Absolute Error (MAE): 0.012395268096935386
# Mean Squared Error (MSE): 0.000246755177173039
# Root Mean Squared Error (RMSE): 0.015708442862774116

# %% [markdown]
# ## GRU

# %%
# Extract hyperparameters
gru_units = hyperparams['gru']['gru_units']
dropout_rate = hyperparams['gru']['dropout_rate']
dense_units = hyperparams['gru']['dense_units']
batch_size = hyperparams['gru']['batch_size']
epochs = hyperparams['gru']['epochs']
use_early_stop = hyperparams['gru']['use_early_stop']
early_stop_patience = hyperparams['gru']['early_stop_patience']
train_needed = hyperparams['gru']['pretrain'] # Whether to train the model

# %%
# Build the GRU model (or load the saved model)
if train_needed:
    model = Sequential()
    model.add(GRU(lstm_units, return_sequences=True, input_shape=(seq_length, 6)))
    model.add(Dropout(dropout_rate))
    model.add(GRU(lstm_units, return_sequences=False))
    model.add(Dropout(dropout_rate))
    model.add(Dense(dense_units))
    model.add(Dense(1))
    
    model.compile(optimizer='adam', loss='mean_squared_error')
else:
    model = load_model('models/SP500_GRU_model.h5')

# %%
# 6. Train the model if needed
if train_needed:
    if use_early_stop:
        early_stop = EarlyStopping(monitor='val_loss', patience=early_stop_patience)
        history = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_test, y_test), callbacks=[early_stop])
    else:
        history = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_test, y_test))

# %%
model.save('models/SP500_GRU_model.h5')
# Out:
# /Users/michaelzhou/miniforge3/envs/tf_m1/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# 7. Evaluate the model 
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# %%
# 8. Make predictions
predictions = model.predict(X_test)

# Inverse transform predictions to the original scale
predictions_rescaled = np.zeros_like(scaled_data)
predictions_rescaled[:, 3] = np.nan  # Fill the 'Close' column
predictions_rescaled[split+seq_length:, 3] = predictions[:, -1]
predictions_rescaled = scaler.inverse_transform(predictions_rescaled)

# Extract actual close prices and ensure they're in the right shape for comparison
actual_prices = scaled_data[split+seq_length:, 3]
actual_prices_rescaled = scaler.inverse_transform(np.hstack((np.zeros((len(actual_prices), scaled_data.shape[1] - 1)), actual_prices.reshape(-1, 1))))
actual_prices_rescaled = actual_prices_rescaled[:, -1]
# Out:
# 2024-07-05 15:46:41.265648: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-07-05 15:46:41.315998: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-07-05 15:46:41.430648: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 106/106 [==============================] - 2s 16ms/step

# %%
# 9. Visualize the results
plt.figure(figsize=(14, 7))
plt.plot(actual_prices, label='Actual Close Price')
plt.plot(predictions[:, -1], label='Predicted Close Price')
plt.legend()
plt.show()

# %%
# 10. Final evaluation of model
mae = mean_absolute_error(actual_prices, predictions[:, -1])
mse = mean_squared_error(actual_prices, predictions[:, -1])
rmse = np.sqrt(mse)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Mean Absolute Error (MAE): 0.006702089241526447
# Mean Squared Error (MSE): 7.228645394777742e-05
# Root Mean Squared Error (RMSE): 0.008502144079452984
